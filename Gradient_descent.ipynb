# %% [markdown]
# <a href="https://colab.research.google.com/github/prateeksingh2001/FDS_Labwork/blob/main/Gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generate random x and y values
x_values = np.random.uniform(-10, 10, 30)
y_values = 3 * x_values + 0.7

# Initialize parameters
w_old = np.random.uniform(-10, 10)
b_old = np.random.uniform(-10, 10)
print(f"Initial w: {w_old}, b: {b_old}")

# Calculate initial prediction and loss
y_cap = w_old * x_values + b_old
Loss = 1/2 * np.mean((y_cap - y_values)**2)

# Gradient descent
for i in range(100):
    # Calculate new parameters
    w_new = w_old - 0.01 * np.mean((y_cap - y_values) * x_values)
    b_new = b_old - 0.01 * np.mean((y_cap - y_values))

    # Update predictions and loss
    y_cap = w_new * x_values + b_new
    Loss = 1/2 * np.mean((y_cap - y_values)**2)

    # Update old parameters
    w_old = w_new
    b_old = b_new

    # Print loss every 10 iterations
    if i % 10 == 0:
        print(f"Iteration {i}: Loss = {Loss}")

print(f"Final w: {w_new}, Final b: {b_new}")

# Plotting the results
plt.scatter(x_values, y_values, color='blue', label='Data Points')
plt.plot(x_values, y_cap, color='orange', label='Fitted Line', linewidth=2)
plt.title('Gradient Descent Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()
# Out:
# Initial w: -8.78026957320185, b: 0.9820091582446793
# Iteration 0: Loss = 1007.4275877157644
# Iteration 10: Loss = 0.162229996141238
# Iteration 20: Loss = 0.08752523087199851
# Iteration 30: Loss = 0.07180649093846529
# Iteration 40: Loss = 0.05891275645004505
# Iteration 50: Loss = 0.04833424994520692
# Iteration 60: Loss = 0.0396552437628186
# Iteration 70: Loss = 0.032534659370348155
# Iteration 80: Loss = 0.026692663060542222
# Iteration 90: Loss = 0.0218996686934116
# Final w: 2.996117655770945, Final b: 0.8928915051914998

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c59abbee7498> in <cell line: 1>()
# ----> 1 x_values
#
# NameError: name 'x_values' is not defined
